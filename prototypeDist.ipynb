# %%
import generateDistribution as genDist

# %%
dist = genDist.distGenerator()

# %% [markdown]
# # Generate Uniform Random Variates

# %%
unif = dist.generateUniform(seed=123,size=10000)
dist.plotDist('Uniform',unif)

# %% [markdown]
# # Generate Exponential Random Variates

# %%
exp = dist.generateExponential(seed=123,size=10000)
dist.plotDist('Exponential',exp)

# %% [markdown]
# # Generate Weibull Random Variates

# %%
wb = dist.generateWeibull(seed=123,size=10000)
dist.plotDist('Weibull',wb)

# %% [markdown]
# # Generate Bernoulli Random Variates

# %%
bern = dist.generateBernoulli(seed=123,size=10000)
dist.plotDist('Bernoulli',bern)

# %% [markdown]
# # Generate Geometric Random Variates

# %%
geom = dist.generateGeometric(seed=123,size=10000)
dist.plotDist('Geometric',geom)

# %% [markdown]
# # Generate Normal Random Variates

# %%
norm = dist.generateNormal(seed1=123,seed2=124,size=10000)
dist.plotDist('Normal',norm)

# %% [markdown]
# # Generate Gamma Random Variates

# %%
gamma = dist.generateGamma(seed=123,size=10000)
dist.plotDist('Gamma',gamma)
